# %%
# !pip install beautifulsoup4

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
search_query='puma+shoes+women&crid'

# %%
base_url='https://www.amazon.in/s?k='

# %%
url=base_url+search_query
url
# Out:
# 'https://www.amazon.in/s?k=puma+shoes+women&crid'

# %%
header={'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36','referer':'https://www.amazon.in/s?k=puma+shoes+women&crid=1J07F6DJYC2Q4&sprefix=puma%2Caps%2C504&ref=nb_sb_ss_ts-doa-p_5_4'}

# %%
search_response=requests.get(url,headers=header)

# %%
search_response.status_code
# Out:
# 200

# %%
search_response.text
# Out:
# '<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n\n<script type=\'text/javascript\'>var ue_t0=ue_t0||+new Date();</script>\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n<!-- sp:end-feature:cs-optimization -->\n<script type=\'text/javascript\'>\nwindow.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\n\nvar ue_csm = window,\n    ue_hob = +new Date();\n(function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.
# ...

# %%
search_response.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='i18n-prefs', value='INR', port=None, port_specified=False, domain='.amazon.in', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1688775119, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='session-id', value='257-1373761-1330555', port=None, port_specified=False, domain='.amazon.in', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1688775119, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='session-id-time', value='2082787201l', port=None, port_specified=False, domain='.amazon.in', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1688775119, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False)]>

# %%
cookie={}
def getAmazonSearch(search_query):
    url="https://www.amazon.in/s?k="+search_query
    print(url)
    page=requests.get(url,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
def Searchasin(asin):
    url="https://www.amazon.in/dp/"+asin
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
def Searchreviews(reviews_link):
    url="https://www.amazon.in/"+reviews_link
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
product_names=[]
response = getAmazonSearch('puma+shoes+women&crid')
soup = BeautifulSoup(response.content)
for i in soup.findAll("span",{'class':"a-size-base-plus a-color-base a-text-normal"}):
    product_names.append(i.text)
# Out:
# https://www.amazon.in/s?k=puma+shoes+women&crid

# %%
product_names
# Out:
# ["Women's Pacer Wn s IDP Sneaker",
#  "Women's Prowl Slip on WNS Cross Trainer",
#  "Women's Pacer WN's Idp Low Boot",
#  "Women's R78 Voyage Sneaker",
#  "Women's Prowl Slip on WNS Cross Trainer",
#  "Women's R78 Voyage Shoes",
#  "Women's Pacer Wn s IDP Sneaker",
#  "Women's Harper WN's Idp Running Shoe",
#  "Women's Radiate Xt Wn S Running Shoes",
#  "Women's Adelina Closed Shoe",
#  "Women's Royce Star Wn S Idp Flat",
#  "Women's Wired Run Slipon WNS Mesh Walking Shoe",
#  "Women's Kendall WNS Running Shoe",
#  "Women's Concave Loop Running Shoe",
#  "Women's Cruise Rider WN's Sneaker",
#  "Women's Carina Slim Sl Sneaker",
#  "Women's Softride Enzo Nxt WN's Walking Shoe",
#  "Women's Game WNS Idp Flat",
#  "Women's' Bra Sports",
#  'unisex-adult Softride Sandal Wns Sport Sandal',
#  "Women's Future Rider Cut-Out WNS Leather Sneaker",
#  "Women's' Regular Pants",
#  "Women's Skye Demi Leather Casual Shoes",
#  "Women's Speed 500 WN's Running Shoe",
#  "Women's Low-Top Trainers",
# ...

# %%
len(product_names)
# Out:
# 76

# %%
data_asin=[]
response=getAmazonSearch('puma+shoes+women&crid')
soup=BeautifulSoup(response.content)
for i in soup.findAll("div",{'class':"sg-col-4-of-12 s-result-item s-asin sg-col-4-of-16 sg-col s-widget-spacing-small sg-col-4-of-20"}):
    data_asin.append(i['data-asin'])
# Out:
# https://www.amazon.in/s?k=puma+shoes+women&crid

# %%
response.status_code
# Out:
# 200

# %%
data_asin
# Out:
# ['B084N52VTX',
#  'B08QCP8LSQ',
#  'B07V8NX9BJ',
#  'B09RGCQ9KG',
#  'B07DC7Z179',
#  'B07NQK12R3',
#  'B09HTJB5W9',
#  'B09P4YBPGT',
#  'B09L5L38QQ',
#  'B09P1LL6HX',
#  'B08NQZGLFW',
#  'B08R3WFSW9',
#  'B09P4ZH1ZQ',
#  'B096WWLF7L',
#  'B09XV7D9BS',
#  'B09YMCZP33',
#  'B09CH89NFT',
#  'B09XV5XSSB',
#  'B09PBCWBH5',
#  'B09XV8C8MF',
#  'B098PCZMMG',
#  'B09HTJHXG6',
#  'B09RG97VYC',
#  'B09RFKC8CS',
#  'B09RG84RN4',
#  'B097C4TXTK',
#  'B09R41JVVM',
#  'B09RFHQJ64',
#  'B081QPKX6C',
#  'B09XV6F5XP',
#  'B097CCBKX3',
#  'B09XBB5MF1',
#  'B09R3W86M2',
#  'B0B2K1J2V5',
#  'B09RG2XNYT',
#  'B09CH5Y85H',
#  'B097C5DSH8',
#  'B07S6NHFR8',
#  'B07DCC7GYJ',
#  'B07BBB388M',
#  'B09V8XNBCV',
#  'B08829PMCX',
#  'B0967W6FNC',
#  'B07F3V8VWY',
#  'B088RJDVDZ',
#  'B09P1MG4Y3',
#  'B09L5JJFNB',
#  'B0B2963Y89']

# %%
len(data_asin)
# Out:
# 48

# %%
link=[]
for i in range(len(data_asin)):
    response=Searchasin(data_asin[i])
    soup=BeautifulSoup(response.content)
    for i in soup.findAll("a",{'data-hook':"see-all-reviews-link-foot"}):
        link.append(i["href"])
# Out:
# https://www.amazon.in/dp/B084N52VTX
# https://www.amazon.in/dp/B08QCP8LSQ
# https://www.amazon.in/dp/B07V8NX9BJ
# https://www.amazon.in/dp/B09RGCQ9KG
# https://www.amazon.in/dp/B07DC7Z179
# https://www.amazon.in/dp/B07NQK12R3
# https://www.amazon.in/dp/B09HTJB5W9
# https://www.amazon.in/dp/B09P4YBPGT
# https://www.amazon.in/dp/B09L5L38QQ
# https://www.amazon.in/dp/B09P1LL6HX
# https://www.amazon.in/dp/B08NQZGLFW
# https://www.amazon.in/dp/B08R3WFSW9
# https://www.amazon.in/dp/B09P4ZH1ZQ
# https://www.amazon.in/dp/B096WWLF7L
# https://www.amazon.in/dp/B09XV7D9BS
# https://www.amazon.in/dp/B09YMCZP33
# https://www.amazon.in/dp/B09CH89NFT
# https://www.amazon.in/dp/B09XV5XSSB
# https://www.amazon.in/dp/B09PBCWBH5
# https://www.amazon.in/dp/B09XV8C8MF
# https://www.amazon.in/dp/B098PCZMMG
# https://www.amazon.in/dp/B09HTJHXG6
# https://www.amazon.in/dp/B09RG97VYC
# https://www.amazon.in/dp/B09RFKC8CS
# https://www.amazon.in/dp/B09RG84RN4
# https://www.amazon.in/dp/B097C4TXTK
# ...

# %%
len(link)
# Out:
# 44

# %%
link
# Out:
# ['/Puma-Womens-Prowl-Slip-Walking/product-reviews/B0B56LRJ8H/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Puma-Womens-R78-Voyage-Shoes/product-reviews/B09JTD73X5/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Puma-Womens-Pacer-IDP-Sneaker/product-reviews/B09ZSR2BRQ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Puma-Womens-Harper-Running-Shoe/product-reviews/B09RFV4DMR/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Puma-Womens-Radiate-Running-Shoes/product-reviews/B09QTYYMXP/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Puma-Womens-Radiate-Running-Shoes/product-reviews/B09QTYYMXP/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Puma-Womens-Adelina-Closed-Shoe/product-reviews/B09RBP1BK7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
# ...

# %%
reviews=[]
for j in range(len(link)):
    for k in range(100):
        response=Searchreviews(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("span",{'data-hook':"review-body"}):
            reviews.append(i.text)
# Out:
# https://www.amazon.in//Puma-Womens-Prowl-Slip-Walking/product-reviews/B0B56LRJ8H/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in//Puma-Womens-Prowl-Slip-Walking/product-reviews/B0B56LRJ8H/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in//Puma-Womens-Prowl-Slip-Walking/product-reviews/B0B56LRJ8H/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in//Puma-Womens-Prowl-Slip-Walking/product-reviews/B0B56LRJ8H/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in//Puma-Womens-Prowl-Slip-Walking/product-reviews/B0B56LRJ8H/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in//Puma-Womens-Prowl-Slip-Walking/product-reviews/B0B56LRJ8H/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# ...

# %%
len(reviews)
# Out:
# 964

# %%
rev={'reviews': reviews}

# %%
review_data=pd.DataFrame.from_dict(rev)
pd.set_option('max_colwidth',800)

# %%
review_data.sample(5)
# Out:
#                                                                                                                                                                                                                                                                     reviews
# 268                                                                                                                                                                                                                                                    \nVery comfortable\n
# 426                                                                                                                                                                                            \nSon súper cómodas, no pesan nada y más bonitas de lo que parecen en foto\n
# ...

# %%
review_data.shape
# Out:
# (964, 1)

# %%
review_data.head(5)
# Out:
#                                                                                                                            reviews
# 0  \nRuns a bit large ...Since no laces its a problemLook fab and comfy so was  dissapointed that correct size was not available\n
# 1                                                                                        \nIts very comfortable and stylish also\n
# 2                                                                                                   \nGood quality at this price\n
# 3                                                \nBought for my mom, she said it was very comfortable to wear and she loves it😊\n
# 4                                                \nGreat as expected, no damage, looks new, you can buy without a second thought\n

# %%
review_data.to_csv('Scrapping reviews.csv',index=False)
